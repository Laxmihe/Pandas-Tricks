# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\laxmi\Documents\META.csv')

print(df)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.230000
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   34.029999
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   31.000000
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   32.000000
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   33.029999
# ...          ...         ...         ...         ...         ...         ...
# 2683  2023-01-18  135.809998  137.250000  132.800003  133.020004  133.020004
# 2684  2023-01-19  132.490005  137.449997  132.139999  136.149994  136.149994
# 2685  2023-01-20  135.889999  139.940002  134.610001  139.369995  139.369995
# 2686  2023-01-23  139.289993  143.759995  138.660004  143.270004  143.270004
# 2687  2023-01-24  141.690002  145.000000  141.360001  143.139999  143.139999
#
#          Volume
# 0     573576400
# ...

# %%
import pandas as pd

df1 = pd.read_csv(r'C:\Users\laxmi\Documents\META.csv')

print(df1)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.230000
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   34.029999
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   31.000000
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   32.000000
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   33.029999
# ...          ...         ...         ...         ...         ...         ...
# 2683  2023-01-18  135.809998  137.250000  132.800003  133.020004  133.020004
# 2684  2023-01-19  132.490005  137.449997  132.139999  136.149994  136.149994
# 2685  2023-01-20  135.889999  139.940002  134.610001  139.369995  139.369995
# 2686  2023-01-23  139.289993  143.759995  138.660004  143.270004  143.270004
# 2687  2023-01-24  141.690002  145.000000  141.360001  143.139999  143.139999
#
#          Volume
# 0     573576400
# ...

# %%
import pandas as pd

df2 = pd.read_csv(r'C:\Users\laxmi\Documents\GOOGL.csv')
print(df2)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-01-25  128.740005  129.399002  126.500504  126.934998  126.934998
# 1    2022-01-26  131.119003  133.000000  127.141998  129.233002  129.233002
# 2    2022-01-27  131.304001  132.652496  128.932495  129.005005  129.005005
# 3    2022-01-28  129.658997  133.356506  128.485001  133.350998  133.350998
# 4    2022-01-31  134.162003  135.473007  132.209503  135.303497  135.303497
# ..          ...         ...         ...         ...         ...         ...
# 247  2023-01-19   90.720001   93.610001   90.629997   93.050003   93.050003
# 248  2023-01-20   95.099998   98.300003   95.019997   98.019997   98.019997
# 249  2023-01-23   97.949997  100.040001   97.500000   99.790001   99.790001
# 250  2023-01-24   98.099998   99.610001   97.199997   97.699997   97.699997
# 251  2023-01-25   95.570000   96.162003   93.760002   94.858299   94.858299
#
#        Volume
# 0    46960000
# 1    49130000
# ...

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\laxmi\Documents\AMZN.csv')
print(df)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2010-01-04   6.812500   6.830500   6.657000   6.695000   6.695000
# 1     2010-01-05   6.671500   6.774000   6.590500   6.734500   6.734500
# 2     2010-01-06   6.730000   6.736500   6.582500   6.612500   6.612500
# 3     2010-01-07   6.600500   6.616000   6.440000   6.500000   6.500000
# 4     2010-01-08   6.528000   6.684000   6.451500   6.676000   6.676000
# ...          ...        ...        ...        ...        ...        ...
# 3266  2022-12-22  85.519997  85.680000  82.250000  83.790001  83.790001
# 3267  2022-12-23  83.250000  85.779999  82.930000  85.250000  85.250000
# 3268  2022-12-27  84.970001  85.349998  83.000000  83.040001  83.040001
# 3269  2022-12-28  82.800003  83.480003  81.690002  81.820000  81.820000
# 3270  2022-12-29  82.870003  84.550003  82.550003  84.180000  84.180000
#
#          Volume
# 0     151998000
# 1     177038000
# 2     143576000
# 3     220604000
# ...

# %%
import pandas as pd

df3 = pd.read_csv(r'C:\Users\laxmi\Documents\AMZN.csv')
print(df3)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2010-01-04   6.812500   6.830500   6.657000   6.695000   6.695000
# 1     2010-01-05   6.671500   6.774000   6.590500   6.734500   6.734500
# 2     2010-01-06   6.730000   6.736500   6.582500   6.612500   6.612500
# 3     2010-01-07   6.600500   6.616000   6.440000   6.500000   6.500000
# 4     2010-01-08   6.528000   6.684000   6.451500   6.676000   6.676000
# ...          ...        ...        ...        ...        ...        ...
# 3266  2022-12-22  85.519997  85.680000  82.250000  83.790001  83.790001
# 3267  2022-12-23  83.250000  85.779999  82.930000  85.250000  85.250000
# 3268  2022-12-27  84.970001  85.349998  83.000000  83.040001  83.040001
# 3269  2022-12-28  82.800003  83.480003  81.690002  81.820000  81.820000
# 3270  2022-12-29  82.870003  84.550003  82.550003  84.180000  84.180000
#
#          Volume
# 0     151998000
# 1     177038000
# 2     143576000
# 3     220604000
# ...

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2012-05-18  42.049999  45.000000  38.000000  38.230000  38.230000
# 1  2012-05-21  36.529999  36.660000  33.000000  34.029999  34.029999
# 2  2012-05-22  32.610001  33.590000  30.940001  31.000000  31.000000
# 3  2012-05-23  31.370001  32.500000  31.360001  32.000000  32.000000
# 4  2012-05-24  32.950001  33.209999  31.770000  33.029999  33.029999
#
#       Volume
# 0  573576400
# 1  168192700
# 2  101786600
# 3   73600000
# 4   50237200

# %%
import pandas as pd
pd.read_csv(r'C:\Users\laxmi\Documents\AAPL.csv')
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-01-04    7.622500    7.660714    7.585000    7.643214    6.515213
# 1     2010-01-05    7.664286    7.699643    7.616071    7.656429    6.526476
# 2     2010-01-06    7.656429    7.686786    7.526786    7.534643    6.422664
# 3     2010-01-07    7.562500    7.571429    7.466071    7.520714    6.410790
# 4     2010-01-08    7.510714    7.571429    7.466429    7.570714    6.453412
# ...          ...         ...         ...         ...         ...         ...
# 3266  2022-12-22  134.350006  134.559998  130.300003  132.229996  132.229996
# 3267  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# 3268  2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# 3269  2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# 3270  2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
#
#          Volume
# 0     493729600
# ...

# %%
import pandas as pd

df4 = pd.read_csv(r'C:\Users\laxmi\Documents\AAPL.csv')

print(df4)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-01-04    7.622500    7.660714    7.585000    7.643214    6.515213
# 1     2010-01-05    7.664286    7.699643    7.616071    7.656429    6.526476
# 2     2010-01-06    7.656429    7.686786    7.526786    7.534643    6.422664
# 3     2010-01-07    7.562500    7.571429    7.466071    7.520714    6.410790
# 4     2010-01-08    7.510714    7.571429    7.466429    7.570714    6.453412
# ...          ...         ...         ...         ...         ...         ...
# 3266  2022-12-22  134.350006  134.559998  130.300003  132.229996  132.229996
# 3267  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# 3268  2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# 3269  2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# 3270  2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
#
#          Volume
# 0     493729600
# ...

# %%
import pandas as pd
pd.read_csv(r'C:\Users\laxmi\Documents\AAPL.csv')

import pandas as pd

df4 = pd.read_csv(r'C:\Users\laxmi\Documents\META.csv')

print(df4)

# %%
import pandas as pd

df4 = pd.read_csv(r'C:\Users\laxmi\Documents\META.csv')

print(df4)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.230000
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   34.029999
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   31.000000
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   32.000000
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   33.029999
# ...          ...         ...         ...         ...         ...         ...
# 2683  2023-01-18  135.809998  137.250000  132.800003  133.020004  133.020004
# 2684  2023-01-19  132.490005  137.449997  132.139999  136.149994  136.149994
# 2685  2023-01-20  135.889999  139.940002  134.610001  139.369995  139.369995
# 2686  2023-01-23  139.289993  143.759995  138.660004  143.270004  143.270004
# 2687  2023-01-24  141.690002  145.000000  141.360001  143.139999  143.139999
#
#          Volume
# 0     573576400
# ...

# %%
df_amzn = pd.read_csv('data/AMZN.csv')
df_ebay = pd.read_csv('data/EBAY.csv')
df1 = pd.read_csv((r'C:\Users\laxmi\Documents\META.csv')
df_see = pd.read_csv(('C:\\Users\\laxmi\\Documents\\AAPL.csv')

# %%
import csv

data = open('C:\\Users\\laxmi\\Documents\\AAPL.csv')
data = csv.reader(data)
print(data)

# %%
import csv

with open('C:\Users\laxmi\Documents\AAPL.csv'','rU') as csvfile:
readit = csv.reader(csvfile,delimiter=',')

for line in readit:
    print line

for line in readit:
    print 'foo'
# Out:
#   File "C:\Users\laxmi\AppData\Local\Temp\ipykernel_9500\2549271997.py", line 3
#     with open('C:\Users\laxmi\Documents\AAPL.csv'','rU') as csvfile:
#                                                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2688.000000  2688.000000  2688.000000  2688.000000  2688.000000
# mean    147.874275   149.757980   146.003795   147.913244   147.913244
# std      86.734656    87.818979    85.682869    86.763257    86.763257
# min      18.080000    18.270000    17.549999    17.730000    17.730000
# 25%      77.967500    78.627499    77.145001    77.980000    77.980000
# 50%     141.620002   143.415000   140.550003   142.065002   142.065002
# 75%     191.070000   193.807499   188.255001   190.854996   190.854996
# max     381.679993   384.329987   378.809998   382.179993   382.179993
#
#              Volume
# count  2.688000e+03
# mean   3.117815e+07
# std    2.713267e+07
# min    5.913100e+06
# 25%    1.622585e+07
# 50%    2.323900e+07
# 75%    3.603725e+07
# max    5.735764e+08

# %%
df.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
corr = df.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_3dfe0_row0_col0, #T_3dfe0_row0_col1, #T_3dfe0_row0_col2, #T_3dfe0_row0_col3, #T_3dfe0_row0_col4, #T_3dfe0_row1_col0, #T_3dfe0_row1_col1, #T_3dfe0_row1_col2, #T_3dfe0_row1_col3, #T_3dfe0_row1_col4, #T_3dfe0_row2_col0, #T_3dfe0_row2_col1, #T_3dfe0_row2_col2, #T_3dfe0_row2_col3, #T_3dfe0_row2_col4, #T_3dfe0_row3_col0, #T_3dfe0_row3_col1, #T_3dfe0_row3_col2, #T_3dfe0_row3_col3, #T_3dfe0_row3_col4, #T_3dfe0_row4_col0, #T_3dfe0_row4_col1, #T_3dfe0_row4_col2, #T_3dfe0_row4_col3, #T_3dfe0_row4_col4, #T_3dfe0_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3dfe0_row0_col5, #T_3dfe0_row2_col5, #T_3dfe0_row3_col5, #T_3dfe0_row4_col5, #T_3dfe0_row5_col0, #T_3dfe0_row5_col1, #T_3dfe0_row5_col2, #T_3dfe0_row5_col3, #T_3dfe0_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3dfe0_row1_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3dfe0">
#   <thead>
#     <tr>
# ...

# %%
from datetime import datetime

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
plt.style.use('seaborn-white')
for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
    plt.rcParams[param] = '#212946'  # bluish dark grey
for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
    plt.rcParams[param] = '0.9'  # very light grey
plt.rcParams.update({"axes.grid": True,"grid.color": "#2A3459"})

# %%
df = df.set_index(pd.to_datetime(df['Date']))

# %%
df.plot(figsize = (15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize = (15,8))
plt.plot(df['Open'])
plt.plot(df['Close'])
plt.legend(['Open','Close'])
plt.title('Open and Close Prices', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Open and Close Prices')

# %%
plt.figure(figsize = (15,8))
plt.plot(df['High'])
plt.plot(df['Low'])
plt.legend(['High','Low'])
plt.title('High and Low Price')
# Out:
# Text(0.5, 1.0, 'High and Low Price')

# %%
df['Adj Close'].rolling(window=30).mean()
# Out:
# Date
# 2012-05-18           NaN
# 2012-05-21           NaN
# 2012-05-22           NaN
# 2012-05-23           NaN
# 2012-05-24           NaN
#                  ...
# 2023-01-18    122.660668
# 2023-01-19    123.118001
# 2023-01-20    123.959667
# 2023-01-23    124.937667
# 2023-01-24    125.864667
# Name: Adj Close, Length: 2688, dtype: float64

# %%
df['Adj Close'].rolling(window = 100).mean()
# Out:
# Date
# 2012-05-18         NaN
# 2012-05-21         NaN
# 2012-05-22         NaN
# 2012-05-23         NaN
# 2012-05-24         NaN
#                 ...
# 2023-01-18    128.0326
# 2023-01-19    127.7063
# 2023-01-20    127.4822
# 2023-01-23    127.3232
# 2023-01-24    127.1830
# Name: Adj Close, Length: 2688, dtype: float64

# %%
plt.figure(figsize = (15,8))
plt.plot(df['Close'])
plt.plot(df['Open'])
plt.legend(['Close', 'Open'])
plt.title('Close and Mean Average', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Close and Mean Average')

# %%
get_RSI(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9500\707801381.py in <module>
# ----> 1 get_RSI(df)
#
# NameError: name 'get_RSI' is not defined

# %%
data = pd.DataFrame()

# %%
column_list = ['Close','High','Low']
df[column_list].plot(figsize = (18,10))
plt.title('Stock')
plt.ylabel('USD Price in ($)')
plt.show()

# %%
fig = plt.figure(figsize = (18,10))
ax = fig.add_subplot(1,1,1)
x_axis = df.index
ax.fill_between(x_axis,df['High'], df['Low'],label =' Bands',color = 'red')
ax.plot(x_axis, df['Close'], color = 'gold',lw = 3, label= 'Close')
ax.plot(x_axis, df['Open'], color = 'blue', lw=3, label='Simple Moving Average')
ax.set_title('Stock')
ax.set_xlabel('Date')
ax.set_ylabel('USD')
plt.xticks(rotation = 45)
ax.legend()
plt.show()

# %%
fig = plt.figure(figsize = (18,10))
ax = fig.add_subplot(1,1,1)
x_axis = df.index
ax.fill_between(x_axis,df['High'], df['Low'],label =' Bands',color = 'red')
ax.plot(x_axis, df['Close'], color = 'gold',lw = 3, label= 'Close')
ax.plot(x_axis, df['Open'], color = 'blue', lw=3, label='Simple Moving Average')
ax.set_title('Stock')
ax.set_xlabel('Date')
ax.set_ylabel('USD')
plt.xticks(rotation = 45)
ax.legend()
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
month = df['Close'].resample('MS').mean()

# %%
decomposition = seasonal_decompose(month, model ='additive')
decomposition.plot()

# %%
train_df = df['High'].iloc[:-4]

# %%
X_train = []
y_train = []

for i in range(2, len(train_df)):
  X_train.append(train_df[i-2:i])
  y_train.append(train_df[i])

# %%
import math
train_len = math.ceil(len(train_df)*0.8)
train_len

# %%
df.isnull().sum().sum()

# %%
df.Close.plot()

# %%
df.Volume.plot()

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from pandas import concat
from math import sqrt
import numpy as np
from numpy import concatenate
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error

# %%
df.isnull().sum()

# %%
values = df.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7, 8, 9, 10]
i = 1
# plot each column
plt.figure(figsize=(20,25))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(df.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from keras.models import Sequential

# %%
from tensorflow.keras.models import Sequential

# %%
model = keras.models.Sequential().

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = pd.read_csv('data/AMZN.csv')
df_ebay = pd.read_csv('data/EBAY.csv')
df_meta = pd.read_csv("C:\Users\laxmi\Documents\META.csv"
df_see = pd.read_csv('data/SEE.csv')

# %%
df1.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2012-05-18  42.049999  45.000000  38.000000  38.230000  38.230000
# 1  2012-05-21  36.529999  36.660000  33.000000  34.029999  34.029999
# 2  2012-05-22  32.610001  33.590000  30.940001  31.000000  31.000000
# 3  2012-05-23  31.370001  32.500000  31.360001  32.000000  32.000000
# 4  2012-05-24  32.950001  33.209999  31.770000  33.029999  33.029999
#
#       Volume
# 0  573576400
# 1  168192700
# 2  101786600
# 3   73600000
# 4   50237200

# %%
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-01-25  128.740005  129.399002  126.500504  126.934998  126.934998
# 1  2022-01-26  131.119003  133.000000  127.141998  129.233002  129.233002
# 2  2022-01-27  131.304001  132.652496  128.932495  129.005005  129.005005
# 3  2022-01-28  129.658997  133.356506  128.485001  133.350998  133.350998
# 4  2022-01-31  134.162003  135.473007  132.209503  135.303497  135.303497
#
#      Volume
# 0  46960000
# 1  49130000
# 2  31950000
# 3  34362000
# 4  39986000

# %%
df3.head()
# Out:
#          Date    Open    High     Low   Close  Adj Close     Volume
# 0  2010-01-04  6.8125  6.8305  6.6570  6.6950     6.6950  151998000
# 1  2010-01-05  6.6715  6.7740  6.5905  6.7345     6.7345  177038000
# 2  2010-01-06  6.7300  6.7365  6.5825  6.6125     6.6125  143576000
# 3  2010-01-07  6.6005  6.6160  6.4400  6.5000     6.5000  220604000
# 4  2010-01-08  6.5280  6.6840  6.4515  6.6760     6.6760  196610000

# %% [markdown]
# df4.head(

# %%
df1.isnull().sum().sum(), df2.isnull().sum().sum(), df3.isnull().sum().sum(), df4.isnull().sum().sum()
# Out:
# (0, 0, 0, 0)

# %%
df1.shape[0], df2.shape[0], df3.shape[0], df4.shape[0]
# Out:
# (2688, 252, 3271, 3271)

# %%
df1[['Date']].nunique()[0], df2[['Date']].nunique()[0], df3[['Date']].nunique()[0], df4[['Date']].nunique()[0]
# Out:
# (2688, 252, 3271, 3271)

# %%
df1['Date'].is_monotonic_increasing, df2['Date'].is_monotonic_increasing, df3['Date'].is_monotonic_increasing, df3['Date'].is_monotonic_increasing
# Out:
# (True, True, True, True)

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df2['Date'] = pd.to_datetime(df2['Date'])
df3['Date'] = pd.to_datetime(df3['Date'])
df4['Date'] = pd.to_datetime(df4['Date'])

# %%
df1.info()  df2.info(), df3.info(), df4.info()
# Out:
#   File "C:\Users\laxmi\AppData\Local\Temp\ipykernel_9500\2758382134.py", line 1
#     df1.info()  df2.info(), df3.info(), df4.info()
#                 ^
# SyntaxError: invalid syntax

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2688 entries, 0 to 2687
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2688 non-null   datetime64[ns]
#  1   Open       2688 non-null   float64
#  2   High       2688 non-null   float64
#  3   Low        2688 non-null   float64
#  4   Close      2688 non-null   float64
#  5   Adj Close  2688 non-null   float64
#  6   Volume     2688 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 147.1 KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    datetime64[ns]
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3271 non-null   datetime64[ns]
#  1   Open       3271 non-null   float64
#  2   High       3271 non-null   float64
#  3   Low        3271 non-null   float64
#  4   Close      3271 non-null   float64
#  5   Adj Close  3271 non-null   float64
#  6   Volume     3271 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 179.0 KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3271 non-null   datetime64[ns]
#  1   Open       3271 non-null   float64
#  2   High       3271 non-null   float64
#  3   Low        3271 non-null   float64
#  4   Close      3271 non-null   float64
#  5   Adj Close  3271 non-null   float64
#  6   Volume     3271 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 179.0 KB

# %%
df1.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2688.000000  2688.000000  2688.000000  2688.000000  2688.000000
# mean    147.874275   149.757980   146.003795   147.913244   147.913244
# std      86.734656    87.818979    85.682869    86.763257    86.763257
# min      18.080000    18.270000    17.549999    17.730000    17.730000
# 25%      77.967500    78.627499    77.145001    77.980000    77.980000
# 50%     141.620002   143.415000   140.550003   142.065002   142.065002
# 75%     191.070000   193.807499   188.255001   190.854996   190.854996
# max     381.679993   384.329987   378.809998   382.179993   382.179993
#
#              Volume
# count  2.688000e+03
# mean   3.117815e+07
# std    2.713267e+07
# min    5.913100e+06
# 25%    1.622585e+07
# 50%    2.323900e+07
# 75%    3.603725e+07
# max    5.735764e+08

# %%
df2.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   112.008338  113.580572  110.380915  111.933412  111.933412
# std     16.061858   16.094546   15.726139   15.899375   15.899375
# min     85.400002   86.519997   83.339996   83.430000   83.430000
# 25%     98.204998   99.779999   97.069997   98.455000   98.455000
# 50%    111.491753  113.312748  109.965000  111.622749  111.622749
# 75%    121.713623  122.960249  119.747500  122.125252  122.125252
# max    151.250000  151.546494  145.522507  148.000000  148.000000
#
#              Volume
# count  2.520000e+02
# mean   3.450729e+07
# std    1.334196e+07
# min    9.701400e+06
# 25%    2.597800e+07
# 50%    3.173255e+07
# 75%    3.991450e+07
# max    1.232000e+08

# %%
df3.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     58.937204    59.610805    58.183281    58.905287    58.905287
# std      54.138607    54.785319    53.410691    54.085034    54.085034
# min       5.296500     5.564500     5.290000     5.430500     5.430500
# 25%      13.343750    13.474500    13.197000    13.326250    13.326250
# 50%      36.325001    36.500000    36.027500    36.382500    36.382500
# 75%      93.025002    94.177250    92.023250    93.138001    93.138001
# max     187.199997   188.654007   184.839493   186.570496   186.570496
#
#              Volume
# count  3.271000e+03
# mean   8.833999e+07
# std    5.309249e+07
# min    1.762600e+07
# 25%    5.610700e+07
# 50%    7.459200e+07
# 75%    1.037120e+08
# max    8.484220e+08

# %%
df4.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     51.274171    51.845876    50.708548    51.297154    49.445122
# std      47.316509    47.926721    46.720115    47.344344    47.810585
# min       6.870357     7.000000     6.794643     6.858929     5.846675
# 25%      18.965894    19.121607    18.779999    18.965536    16.625739
# 50%      29.745001    29.980000    29.555000    29.812500    27.385101
# 75%      56.897499    57.256248    56.435000    56.761250    54.876044
# max     182.630005   182.940002   179.119995   182.009995   180.959732
#
#              Volume
# count  3.271000e+03
# mean   2.563255e+08
# std    2.225768e+08
# min    3.519590e+07
# 25%    1.023724e+08
# 50%    1.666740e+08
# 75%    3.457554e+08
# max    1.880998e+09

# %%
(df1['Date'] - df1['Date'].shift(1)).value_counts()
# Out:
# 1 days    2102
# 3 days     486
# 4 days      71
# 2 days      27
# 5 days       1
# Name: Date, dtype: int64

# %%
df1 = df1.set_index('Date')
df2 = df2.set_index('Date')
df3 = df3.set_index('Date')
df4= df4.set_index('Date')

# %%
df1.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-05-18  42.049999  45.000000  38.000000  38.230000  38.230000  573576400
# 2012-05-21  36.529999  36.660000  33.000000  34.029999  34.029999  168192700
# 2012-05-22  32.610001  33.590000  30.940001  31.000000  31.000000  101786600
# 2012-05-23  31.370001  32.500000  31.360001  32.000000  32.000000   73600000
# 2012-05-24  32.950001  33.209999  31.770000  33.029999  33.029999   50237200

# %%
fig, ax = plt.subplots(figsize=(8, 6))
half_year_locator = mdates.YearLocator(4)
ax.xaxis.set_major_locator(half_year_locator)
plt.title('Opening market price')
plt.xlabel('date')
plt.ylabel('price')
ax.plot(df1.index, df1['Open'], label = 'META')
ax.plot(df2.index, df2['Open'], label = "GOOGLE")
ax.plot(df3.index, df3['Open'], label = "AMAZON")
ax.plot(df4.index, df4['Open'], label = "AAPL")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
half_year_locator = mdates.YearLocator(1)
ax.xaxis.set_major_locator(half_year_locator)
plt.title('Opening market price')
plt.xlabel('date')
plt.ylabel('price')
ax.plot(df1.index[-1500:], df1['Open'][-1500:], label = 'META')
ax.plot(df2.index[-1500:], df2['Open'][-1500:], label = "GOOGLE")
ax.plot(df3.index[-1500:], df3['Open'][-1500:], label = "AMAZON")
ax.plot(df4.index[-1500:], df4['Open'][-1500:], label = "AAPL")
plt.legend()
plt.show()

# %%
df1['MO25'] = df1['Open'].rolling(25).mean()
df2['MO25'] = df2['Open'].rolling(25).mean()
df3['MO25'] = df3['Open'].rolling(25).mean()
df4['MO25'] = df4['Open'].rolling(25).mean()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
half_year_locator = mdates.YearLocator(1)
ax.xaxis.set_major_locator(half_year_locator)
plt.title('Moving averages for opening market price (25days)')
plt.xlabel('date')
plt.ylabel('price')
ax.plot(df1.index[-1500:], df1['MO25'][-1500:], label = 'META')
ax.plot(df2.index[-1500:], df2['MO25'][-1500:], label = "GOOGLE")
ax.plot(df3.index[-1500:], df3['MO25'][-1500:], label = "AMAZON")
ax.plot(df4.index[-1500:], df4['MO25'][-1500:], label = "AAPL")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
half_year_locator = mdates.YearLocator(4)
ax.xaxis.set_major_locator(half_year_locator)
plt.title('Closing market price')
plt.xlabel('date')
plt.ylabel('price')
ax.plot(df1.index, df1['Close'], label = 'META')
ax.plot(df2.index, df2['Close'], label = "GOOGLE")
ax.plot(df3.index, df3['Close'], label = "AMAZON")
ax.plot(df4.index, df4['Close'], label = "AAPL")
plt.legend()
plt.show()

# %%
since_date = df1.index[0]

fig, ax = plt.subplots(figsize=(8, 6))
half_year_locator = mdates.YearLocator(4)
ax.xaxis.set_major_locator(half_year_locator)
plt.title('Volume of stock traded')
plt.xlabel('date')
plt.ylabel('number of shares')
ax.plot(df1.index, df1['Volume'], label = 'META')
ax.plot(df2.index, df2['Volume'], label = "GOOGLE")
ax.plot(df3.index, df_meta['Volume'], label = "AMAZON")
ax.plot(df4.index[df4.index>=pd.to_datetime(since_date)], df_see['Volume'][df_see.index>=pd.to_datetime(since_date)], label = "SEE")
plt.legend()
plt.show()
